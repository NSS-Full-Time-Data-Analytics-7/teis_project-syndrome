# %%
import seaborn as sns
import pandas as pd
import operator 
import time 
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
tm = pd.read_csv('../data/TEIS_Monthly.csv')

# %%
tr = pd.read_csv('../data/TEIS_Recent.csv')

# %%
teis_merge = pd.merge(tm,tr, how = 'outer')

# %%
teis_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 191563 entries, 0 to 191562
# Data columns (total 36 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   POE                          191563 non-null  object
#  1   Child ID                     191563 non-null  int64
#  2   DOB                          191563 non-null  object
#  3   County Name                  191555 non-null  object
#  4   County SES                   113251 non-null  object
#  5   Child Phase                  191563 non-null  object
#  6   Active                       191563 non-null  object
#  7   Service Coordinator          191562 non-null  object
#  8   Notification/ Referral Date  113256 non-null  object
#  9   Parent Consent Date          127024 non-null  object
#  10  Referral Source Type Name    191563 non-null  object
#  11  Initial Eligibility          107264 non-null  object
# ...

# %%
teis_merge.count()
# Out:
# POE                            191563
# Child ID                       191563
# DOB                            191563
# County Name                    191555
# County SES                     113251
# Child Phase                    191563
# Active                         191563
# Service Coordinator            191562
# Notification/ Referral Date    113256
# Parent Consent Date            127024
# Referral Source Type Name      191563
# Initial Eligibility            107264
# Initial Eligibility Date       107264
# Initial IFSP Date               53185
# Latest IFSP Date                51996
# Exit Reason                    106768
# Exit Date                      106768
# Fiscal Year                    113256
# Notification Month             113256
# Tenn Region                    113256
# Referral Count                 113256
# Evaluation Count                59469
# Eligibility Count               40762
# IFSP Count                       8010
# Service Coordinator Counter    113256
# ...

# %%
tm.count()
# Out:
# POE                            113256
# Child ID                       113256
# DOB                            113256
# County Name                    113251
# County SES                     113251
# Child Phase                    113256
# Active                         113256
# Service Coordinator            113255
# Notification/ Referral Date    113256
# Parent Consent Date             58101
# Referral Source Type Name      113256
# Initial Eligibility             40762
# Initial Eligibility Date        40762
# Initial IFSP Date                8010
# Latest IFSP Date                 7983
# Exit Reason                     39366
# Exit Date                       39366
# Fiscal Year                    113256
# Notification Month             113256
# Tenn Region                    113256
# Referral Count                 113256
# Evaluation Count                59469
# Eligibility Count               40762
# IFSP Count                       8010
# Service Coordinator Counter    113256
# ...

# %%
tr.count()
# Out:
# POE                          96580
# Child ID                     96580
# DOB                          96580
# County Name                  96576
# County SES                   96576
# Child Phase                  96580
# Active                       96580
# Service Coordinator          96579
# Notification Date            96580
# Parent Consent Date          70026
# Referral Source Type Name    96580
# Initial Eligibility          68221
# Initial Eligibility Date     68221
# Initial IFSP Date            45493
# Latest IFSP Date             44331
# Exit Reason                  85194
# Exit Date                    85194
# dtype: int64

# %%
teis_merge.groupby('Child ID').count()
# Out:
#           POE  DOB  County Name  County SES  Child Phase  Active  \
# Child ID
# 104085      1    1            1           1            1       1
# 350065      1    1            1           1            1       1
# 351755      2    2            2           1            2       2
# 353800      1    1            1           1            1       1
# 353805      2    2            2           1            2       2
# ...       ...  ...          ...         ...          ...     ...
# 531592      1    1            1           0            1       1
# 531593      1    1            1           0            1       1
# 531594      1    1            1           0            1       1
# 531595      1    1            1           0            1       1
# 531596      1    1            1           0            1       1
#
#           Service Coordinator  Notification/ Referral Date  \
# Child ID
# 104085                      0                            1
# ...

# %%
tm.groupby('Child ID').count()
# Out:
#           POE  DOB  County Name  County SES  Child Phase  Active  \
# Child ID
# 104085      1    1            1           1            1       1
# 350065      1    1            1           1            1       1
# 351755      1    1            1           1            1       1
# 353800      1    1            1           1            1       1
# 353805      1    1            1           1            1       1
# ...       ...  ...          ...         ...          ...     ...
# 529587      1    1            1           1            1       1
# 529597      1    1            1           1            1       1
# 529599      1    1            1           1            1       1
# 529606      1    1            1           1            1       1
# 529609      1    1            1           1            1       1
#
#           Service Coordinator  Notification/ Referral Date  \
# Child ID
# 104085                      0                            1
# ...

# %%
slicertm = tm[['Child ID', 'POE', 'Notification/ Referral Date','Fiscal Year', 'County Name','Referral Year']]
slicertm
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 slicertm = tm[['Child ID', 'POE', 'Notification/ Referral Date','Fiscal Year', 'County Name','Referral Year']]
#       2 slicertm
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
dups_tm = slicertm.loc[slicertm.duplicated(subset='Child ID', keep=False)]
dups_tm

# %%
dups_tm.sort_values(by = "Child ID")

# %%
dups_tm.groupby('Child ID').count()

# %%
dups_tm.groupby(['POE', 'Child ID']).count()

# %%
dups_tm.groupby('Fiscal Year').count()

# %%
dups_double = dups_tm.groupby(['POE', 'Child ID'], as_index = False).count()
dups_370631 = dups_double.loc[dups_double['Child ID']== 370631]
dups_370631

# %%
dups_tm_child = dups_tm.groupby('Child ID', as_index = False).count()
dups_tm_child.value_counts('Child ID')

# %%
tm['Referral Year'] = tm['Notification/ Referral Date'].str[-4:]
print(tm)

# %%
tm.count()

# %%
tm.head(9000)

# %%
tm['IFSP Count']
