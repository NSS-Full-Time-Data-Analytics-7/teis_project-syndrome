# %%
import seaborn as sns
import pandas as pd
import operator 
import time 
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
tm = pd.read_csv('../data/TEIS_Monthly.csv')

# %%
tr = pd.read_csv('../data/TEIS_recent.csv')

# %%
TM_referral = tm[['Referral Source Type Name','IFSP Count']].fillna(0)
TM_referral.head(5)
# Out:
#   Referral Source Type Name  IFSP Count
# 0             Foster Parent         0.0
# 1                       DCS         0.0
# 2                       DCS         0.0
# 3                       PCP         1.0
# 4                    Parent         1.0

# %%
TEIS_Referral_Group_Sum = TM_referral.groupby(('Referral Source Type Name')).sum()
TEIS_Referral_Group
# Out:
#                                IFSP Count
# Referral Source Type Name
# CAPTA                                 0.0
# Child Care provider                  40.0
# Community/Child Find Activity        26.0
# DCS                                 728.0
# DHS                                   0.0
# DMRS                                  1.0
# Dept. of Health                     212.0
# EIRA                                 20.0
# Early Head Start/Head Start          60.0
# Family and Friends                   55.0
# Foster Parent                        72.0
# Hospital                            422.0
# LEA                                   0.0
# NHS                                  15.0
# NICU                                184.0
# OT                                    9.0
# Other                               221.0
# Other Health Care Provider          171.0
# PCP                                3127.0
# PICU                                  3.0
# PT                                   85.0
# ...

# %%
TEIS_Referral_Group_Count = TM_referral.groupby(('Referral Source Type Name')).count()
TEIS_Referral_Group
# Out:
#                                IFSP Count
# Referral Source Type Name
# CAPTA                                 0.0
# Child Care provider                  40.0
# Community/Child Find Activity        26.0
# DCS                                 728.0
# DHS                                   0.0
# DMRS                                  1.0
# Dept. of Health                     212.0
# EIRA                                 20.0
# Early Head Start/Head Start          60.0
# Family and Friends                   55.0
# Foster Parent                        72.0
# Hospital                            422.0
# LEA                                   0.0
# NHS                                  15.0
# NICU                                184.0
# OT                                    9.0
# Other                               221.0
# Other Health Care Provider          171.0
# PCP                                3127.0
# PICU                                  3.0
# PT                                   85.0
# ...

# %%
TEIS_Referral_Group_Sum/TEIS_Referral_Group_Count*100
# Out:
#                                IFSP Count
# Referral Source Type Name
# CAPTA                            0.000000
# Child Care provider              9.501188
# Community/Child Find Activity    6.753247
# DCS                              2.872248
# DHS                              0.000000
# DMRS                           100.000000
# Dept. of Health                  5.838612
# EIRA                             5.830904
# Early Head Start/Head Start      5.917160
# Family and Friends              10.848126
# Foster Parent                   17.433414
# Hospital                         5.874165
# LEA                              0.000000
# NHS                              6.849315
# NICU                             5.693069
# OT                              10.975610
# Other                            8.629442
# Other Health Care Provider       7.579787
# PCP                              7.301980
# PICU                            11.538462
# PT                              13.957307
# ...
