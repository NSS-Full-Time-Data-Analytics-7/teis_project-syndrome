# %% [markdown]
# **What is the rate of re-referral?**
#
# How many children have multiple referrals (by year or by Point of  Entry Office (POE))?
#
# 1. count = 15267

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %matplotlib inline

# %%
monthlydf = pd.read_csv('../data/teis_monthly.csv')   
monthlydf.head()
# Out:
#   POE  Child ID        DOB County Name    County SES   Child Phase Active  \
# 0  ET    403339   8/9/2014      Blount  Transitional   Eligibility      A
# 1  FT    404085  7/31/2013      Unicoi       At-Risk  Notification      I
# 2  FT    403623   2/5/2016    Sullivan  Transitional   Eligibility      A
# 3  FT    404157  12/6/2015    Sullivan  Transitional          IFSP      A
# 4  FT    404154  4/18/2015     Hawkins       At-Risk          IFSP      A
#
#             Service Coordinator Notification/ Referral Date  \
# 0                  Kristi Borer                    7/1/2016
# 1  Jennifer Terranera - 45 days                    7/1/2016
# 2                   Amy Talbert                    7/1/2016
# 3                Candice Cradic                    7/1/2016
# 4                Kathy Jeffries                    7/1/2016
#
#   Parent Consent Date  ... Service Coordinator Counter Fiscal Year.1  \
# 0              7/1/16  ...                           1          2016
# ...

# %%
monthlydf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113256 entries, 0 to 113255
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   POE                          113256 non-null  object
#  1   Child ID                     113256 non-null  int64
#  2   DOB                          113256 non-null  object
#  3   County Name                  113251 non-null  object
#  4   County SES                   113251 non-null  object
#  5   Child Phase                  113256 non-null  object
#  6   Active                       113256 non-null  object
#  7   Service Coordinator          113255 non-null  object
#  8   Notification/ Referral Date  113256 non-null  object
#  9   Parent Consent Date          58101 non-null   object
#  10  Referral Source Type Name    113256 non-null  object
#  11  Initial Eligibility          40762 non-null   object
# ...

# %%
# extract year from Notification/ Referral and put it in new columm Referral Year
monthlydf['Referral Year'] = pd.DatetimeIndex(monthlydf['Notification/ Referral Date']).year
monthlydf
# Out:
#        POE  Child ID        DOB County Name    County SES   Child Phase  \
# 0       ET    403339   8/9/2014      Blount  Transitional   Eligibility
# 1       FT    404085  7/31/2013      Unicoi       At-Risk  Notification
# 2       FT    403623   2/5/2016    Sullivan  Transitional   Eligibility
# 3       FT    404157  12/6/2015    Sullivan  Transitional          IFSP
# 4       FT    404154  4/18/2015     Hawkins       At-Risk          IFSP
# ...     ..       ...        ...         ...           ...           ...
# 113251  UC    528759   4/7/2021      Sumner   Competitive    Evaluation
# 113252  UC    528534  3/13/2022      Sumner   Competitive          IFSP
# 113253  UC    528430   1/5/2022  Cumberland  Transitional   Eligibility
# 113254  UC    528253  9/12/2020      Sumner   Competitive          IFSP
# 113255  UC    528535   2/8/2022       Smith  Transitional    Evaluation
#
#        Active           Service Coordinator Notification/ Referral Date  \
# ...

# %% [markdown]
# monthlydf['Referral Year'] = monthlydf['Notification/ Referral Date'].str[-4:]
# monthlydf

# %%
monthlydf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113256 entries, 0 to 113255
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   POE                          113256 non-null  object
#  1   Child ID                     113256 non-null  int64
#  2   DOB                          113256 non-null  object
#  3   County Name                  113251 non-null  object
#  4   County SES                   113251 non-null  object
#  5   Child Phase                  113256 non-null  object
#  6   Active                       113256 non-null  object
#  7   Service Coordinator          113255 non-null  object
#  8   Notification/ Referral Date  113256 non-null  object
#  9   Parent Consent Date          58101 non-null   object
#  10  Referral Source Type Name    113256 non-null  object
#  11  Initial Eligibility          40762 non-null   object
# ...

# %%
slicerdf = monthlydf[['Child ID', 'POE', 'Referral Year']]
slicerdf
# Out:
#         Child ID POE  Referral Year
# 0         403339  ET           2016
# 1         404085  FT           2016
# 2         403623  FT           2016
# 3         404157  FT           2016
# 4         404154  FT           2016
# ...          ...  ..            ...
# 113251    528759  UC           2022
# 113252    528534  UC           2022
# 113253    528430  UC           2022
# 113254    528253  UC           2022
# 113255    528535  UC           2022
#
# [113256 rows x 3 columns]

# %%
dups_df = slicerdf.loc[slicerdf.duplicated(subset='Child ID', keep=False)]
dups_df.sort_values(by = "Child ID")
# Out:
#         Child ID POE  Referral Year
# 8326      360966  ET           2017
# 6007      360966  ET           2016
# 5441      361021  ET           2016
# 6658      361021  ET           2016
# 5189      361038  GN           2016
# ...          ...  ..            ...
# 111573    527636  ET           2022
# 110585    527691  MD           2022
# 112414    527691  MD           2022
# 111752    527751  FT           2022
# 109913    527751  FT           2022
#
# [33573 rows x 3 columns]

# %%
dups_df.groupby('Child ID', as_index=False).count()  
#15,267 child ID's are duplicates which equates to the # of children that have been referred more than once
# Out:
#        Child ID  POE  Referral Year
# 0        360966    2              2
# 1        361021    2              2
# 2        361038    2              2
# 3        361040    2              2
# 4        363098    2              2
# ...         ...  ...            ...
# 15262    527583    2              2
# 15263    527603    2              2
# 15264    527636    2              2
# 15265    527691    2              2
# 15266    527751    2              2
#
# [15267 rows x 3 columns]

# %%
dups_double = dups_df.groupby(['POE', 'Child ID'], as_index = False).count()
dups_370631 = dups_double.loc[dups_double['Child ID']== 370631]
dups_370631

#this is proof of duplicates in different POE's. (also child ID 382142)
# Out:
#       POE  Child ID  Referral Year
# 7438   MD    370631              1
# 10980  SC    370631              1

# %%
dups_df_Child = dups_df.groupby('Child ID', as_index=False).count()
dups_df_Child.value_counts('Child ID')
# Out:
# Child ID
# 360966    1
# 478239    1
# 478181    1
# 478186    1
# 478188    1
#          ..
# 435298    1
# 435299    1
# 435308    1
# 435313    1
# 527751    1
# Length: 15267, dtype: int64

# %% [markdown]
# **used below calculations instead**
#
# len(dups_df_Child)/len(monthlydf) * 100
# print("13.48%")
# #15267/qty child ID's divided by total entries in monthly data (113256/qty)

# %%
len(monthlydf) - len(dups_df) + len(dups_df_Child)
# Out:
# 94950

# %%
len(dups_df_Child)/(len(monthlydf) - len(dups_df) + len(dups_df_Child)) * 100   
print("16.08%")
#15267/qty unique child ID's divided by total Child ID's in monthly data (94950/qty)
# Out:
# 16.08%

# %% [markdown]
# **What is the rate of re-referral?**
#
# How many children have multiple referrals (by year or by Point of  Entry Office (POE))?
#  - group by year

# %%
Rerefs = slicerdf.loc[~slicerdf.duplicated(subset='Child ID', keep='first')]
Rerefs.sort_values(by = "Child ID")
# Out:
#         Child ID POE  Referral Year
# 25415     104085  GN           2018
# 2092      350065  UC           2016
# 437       351755  NW           2016
# 3369      353800  FT           2016
# 1552      353805  UC           2016
# ...          ...  ..            ...
# 113190    529587  UC           2022
# 112947    529597  SE           2022
# 112949    529599  SE           2022
# 111729    529606  FT           2022
# 111777    529609  FT           2022
#
# [94950 rows x 3 columns]

# %%
TotalRef = slicerdf[['Child ID', 'Referral Year']].groupby('Referral Year').count().reset_index() 
TotalRef 

#Total Child ID's per year = Total Referrals per year including duplicates  113,256
#change child ID to total referrals
# Out:
#    Referral Year  Child ID
# 0           2016      7882
# 1           2017     16897
# 2           2018     19075
# 3           2019     20289
# 4           2020     18957
# 5           2021     20863
# 6           2022      9293

# %%
RefefsbyYear = TotalRef - RY
RefefsbyYear
#total 18306 re-referrals
# Out:
#    Referral Year  Child ID
# 0              0      5973
# 1              0     11971
# 2              0     13170
# 3              0     14000
# 4              0     12554
# 5              0     14689
# 6              0      7326

# %%
RY = dups_df[['Child ID', 'Referral Year']].groupby('Referral Year').count().reset_index() 
RY 

#Total Child ID's per year x the # of times they are duplicated over the data = 33573
#Change Child ID to
# Out:
#    Referral Year  Child ID
# 0           2016      1909
# 1           2017      4926
# 2           2018      5905
# 3           2019      6289
# 4           2020      6403
# 5           2021      6174
# 6           2022      1967

# %%
RY['Percent'] = (RY['Child ID']/len(dups_df_Child) *100).round(decimals =2)
RY

#count of Child ID by year divided by 33573
# Out:
#    Referral Year  Child ID  Percent
# 0           2016      1909    12.50
# 1           2017      4926    32.27
# 2           2018      5905    38.68
# 3           2019      6289    41.19
# 4           2020      6403    41.94
# 5           2021      6174    40.44
# 6           2022      1967    12.88

# %% [markdown]
# **What is the rate of re-referral?**
#
# How many children have multiple referrals (by year or by Point of  Entry Office (POE))?
#  - group by POE

# %%
POE = dups_df[['Child ID', 'POE']].groupby('POE').count().reset_index() 
POE
# Out:
#   POE  Child ID
# 0  ET      6161
# 1  FT      3358
# 2  GN      6215
# 3  MD      5695
# 4  NW      1986
# 5  SC      3966
# 6  SE      2018
# 7  SW      1746
# 8  UC      2428

# %%
POE['Percent'] = (POE['Child ID']/len(dups_df) *100).round(decimals =2)
POE

#count of Child ID Divided by 33573
# Out:
#   POE  Child ID  Percent
# 0  ET      6161    18.35
# 1  FT      3358    10.00
# 2  GN      6215    18.51
# 3  MD      5695    16.96
# 4  NW      1986     5.92
# 5  SC      3966    11.81
# 6  SE      2018     6.01
# 7  SW      1746     5.20
# 8  UC      2428     7.23

# %%
ALL = dups_df.groupby(['Referral Year', 'POE']).count()
ALL
# Out:
#                    Child ID
# Referral Year POE
# 2016          ET        388
#               FT        223
#               GN        366
#               MD        382
#               NW         86
# ...                     ...
# 2022          NW        108
#               SC        245
#               SE        147
#               SW         92
#               UC        168
#
# [63 rows x 1 columns]

# %%
ALL['Percent'] = (ALL['Child ID']/len(dups_df) *100).round(decimals =2)
ALL.head(9)


#count of Child ID Divided by the total for each year - can't figure this one out
#T should be 388/1909 = 20.32%
# Out:
#                    Child ID  Percent
# Referral Year POE
# 2016          ET        388     1.16
#               FT        223     0.66
#               GN        366     1.09
#               MD        382     1.14
#               NW         86     0.26
#               SC        196     0.58
#               SE         68     0.20
#               SW         96     0.29
#               UC        104     0.31

# %% [markdown]
# teiscount_df = teis_df.drop_duplicates(subset = ['child id'], keep = False)
# teiscount_df
