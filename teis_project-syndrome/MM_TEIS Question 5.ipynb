# %%
import pandas as pd
import operator
import time
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
Final_Data = pd.read_csv('../teis_project-syndrome/data/teis_final_data.csv')

# %%
Final_Data.columns
# Out:
# Index(['Child ID', 'Notification Date', 'Fiscal Year', 'Notification Month',
#        'Tenn Region', 'Fiscal Year.1', 'third_DOB', 'Late Referral', 'Qtr',
#        'POE', 'DOB', 'County Name', 'County SES', 'Child Phase', 'Active',
#        'Service Coordinator', 'Parent Consent', 'Initial Eligibility',
#        'Initial Eligibility Date', 'Initial IFSP Date', 'Latest IFSP',
#        'Exit Reason', 'Exit Date', 'Referral Source Type Name', 'Year'],
#       dtype='object')

# %%
Final_Data.head(5)
# Out:
#    Child ID Notification Date Fiscal Year Notification Month Tenn Region  \
# 0    104085        2018-01-20   2017-2018                Jan      Middle
# 1    350065        2016-08-17   2016-2017                Aug      Middle
# 2    351755        2016-07-12   2016-2017                Jul     Western
# 3    353800        2016-09-14   2016-2017                Sep     Eastern
# 4    353805        2016-08-05   2016-2017                Aug      Middle
#
#    Fiscal Year.1   third_DOB  Late Referral  Qtr POE  ...  \
# 0         2017.0  2010-07-07            1.0  3.0  GN  ...
# 1         2016.0  2016-10-15            1.0  1.0  UC  ...
# 2         2016.0  2016-11-13            NaN  1.0  NW  ...
# 3         2016.0  2016-10-01            1.0  1.0  FT  ...
# 4         2016.0  2016-12-04            NaN  1.0  UC  ...
#
#             Service Coordinator Parent Consent Initial Eligibility  \
# 0                           NaN            NaN                 NaN
# 1               Steven Scarlett            NaN                 NaN
# 2                     Rene Bard     2016-07-12          Ineligible
# 3  Jennifer Terranera - 45 days            NaN                 NaN
# 4                    Anna Bolin     2016-08-15            Eligible
#
#   Initial Eligibility Date Initial IFSP Date Latest IFSP  \
# 0                      NaN               NaN         NaN
# 1                      NaN               NaN         NaN
# 2                8/25/2016               NaN         NaN
# 3                      NaN               NaN         NaN
# 4                10/5/2016        10/10/2016         NaN
#
#                                Exit Reason   Exit Date  \
# 0                        Unable to contact  2010-01-25
# 1                        Unable to contact  2016-08-31
# 2                    Ineligible for Part C  2016-08-25
# 3               Referral less than 45 days  2016-09-15
# 4  618 - Part B eligibility not determined  2016-12-03
#
#   Referral Source Type Name  Year
# 0                       DCS  2018
# 1                       PCP  2016
# 2                    Parent  2016
# 3                    Parent  2016
# 4           Dept. of Health  2016
#
# [5 rows x 25 columns]

# %%
Final_Data['Notification Date'] = pd.to_datetime(Final_Data['Notification Date'])
Final_Data['Notification Date']
# Out:
# 0        2018-01-20
# 1        2016-08-17
# 2        2016-07-12
# 3        2016-09-14
# 4        2016-08-05
#             ...
# 115519   2022-07-01
# 115520   2022-07-01
# 115521   2022-07-01
# 115522   2022-07-01
# 115523   2022-07-01
# Name: Notification Date, Length: 115524, dtype: datetime64[ns]

# %%
Final_Data['DOB'] = pd.to_datetime(Final_Data['DOB'])
Final_Data['DOB']
# Out:
# 0        2007-07-07
# 1        2013-10-15
# 2        2013-11-13
# 3        2013-10-01
# 4        2013-12-04
#             ...
# 115519   2020-05-20
# 115520   2021-12-07
# 115521   2022-06-21
# 115522   2022-06-17
# 115523   2019-12-26
# Name: DOB, Length: 115524, dtype: datetime64[ns]

# %%
TEIS_Exit = Final_Data[['POE', 'Service Coordinator', 'Child ID', 'DOB', 'third_DOB', 'Exit Reason','Exit Date','Child Phase']].fillna(0)
TEIS_Exit
# Out:
#        POE           Service Coordinator  Child ID        DOB   third_DOB  \
# 0       GN                             0    104085 2007-07-07  2010-07-07
# 1       UC               Steven Scarlett    350065 2013-10-15  2016-10-15
# 2       NW                     Rene Bard    351755 2013-11-13  2016-11-13
# 3       FT  Jennifer Terranera - 45 days    353800 2013-10-01  2016-10-01
# 4       UC                    Anna Bolin    353805 2013-12-04  2016-12-04
# ...     ..                           ...       ...        ...         ...
# 115519  GN                   Kim Correll    531592 2020-05-20           0
# 115520  GN                   Kim Correll    531593 2021-12-07           0
# 115521  GN                   Kim Correll    531594 2022-06-21           0
# 115522  GN                   Kim Correll    531595 2022-06-17           0
# 115523  SC                   Kim Correll    531596 2019-12-26           0
#
#                                     Exit Reason   Exit Date   Child Phase
# 0                             Unable to contact  2010-01-25  Notification
# 1                             Unable to contact  2016-08-31     Screening
# 2                         Ineligible for Part C  2016-08-25   Eligibility
# 3                    Referral less than 45 days  2016-09-15  Notification
# 4       618 - Part B eligibility not determined  2016-12-03          IFSP
# ...                                         ...         ...           ...
# 115519                                        0           0  Notification
# 115520                                        0           0  Notification
# 115521                                        0           0  Notification
# 115522                                        0           0  Notification
# 115523                                        0           0  Notification
#
# [115524 rows x 8 columns]

# %%
TEIS_Exit = TEIS_Exit[TEIS_Exit['Child Phase']== "IFSP"]
TEIS_Exit
# Out:
#        POE Service Coordinator  Child ID        DOB   third_DOB  \
# 4       UC          Anna Bolin    353805 2013-12-04  2016-12-04
# 8       ET        Kristi Borer    354276 2013-12-24  2016-12-24
# 15      ET         Karen Stock    358011 2014-02-02  2017-02-02
# 16      FT  Jennifer Terranera    358031 2014-01-14  2017-01-14
# 18      FT     Kathy  Jeffries    358765 2014-02-04  2017-02-04
# ...     ..                 ...       ...        ...         ...
# 114258  NW      Brittany Smith    530139 2020-05-06           0
# 114296  GN     Katrina Mangrum    530190 2020-12-01           0
# 114301  SC        Andrea Smith    530196 2020-06-06           0
# 114319  UC     Candace Peacock    530214 2021-01-12           0
# 114363  SC         Carla Beard    530258 2019-12-05           0
#
#                                     Exit Reason   Exit Date Child Phase
# 4       618 - Part B eligibility not determined  2016-12-03        IFSP
# 8                         618 - Parent withdraw  2016-09-22        IFSP
# 15                        618 - Part B eligible  2017-02-01        IFSP
# 16                        618 - Part B eligible  2017-01-13        IFSP
# 18                        618 - Part B eligible  2017-02-03        IFSP
# ...                                         ...         ...         ...
# 114258                                        0           0        IFSP
# 114296                                        0           0        IFSP
# 114301                                        0           0        IFSP
# 114319                                        0           0        IFSP
# 114363                                        0           0        IFSP
#
# [45519 rows x 8 columns]

# %%
TEIS_Exit = TEIS_Exit[TEIS_Exit['Exit Date'] != 0]
TEIS_Exit
# Out:
#        POE     Service Coordinator  Child ID        DOB   third_DOB  \
# 4       UC              Anna Bolin    353805 2013-12-04  2016-12-04
# 8       ET            Kristi Borer    354276 2013-12-24  2016-12-24
# 15      ET             Karen Stock    358011 2014-02-02  2017-02-02
# 16      FT      Jennifer Terranera    358031 2014-01-14  2017-01-14
# 18      FT         Kathy  Jeffries    358765 2014-02-04  2017-02-04
# ...     ..                     ...       ...        ...         ...
# 112126  SC              Kelly Holt    527606 2021-12-09  2024-12-09
# 112129  MD          Torkwase Smith    527609 2019-08-26  2022-08-26
# 112174  SC   Brittney Blalock Rose    527688 2020-04-24  2023-04-24
# 112689  MD          Marian Kingery    528318 2021-09-26  2024-09-26
# 113003  ET  Mischelle Helterbridle    528675 2020-10-11  2023-10-11
#
#                                     Exit Reason   Exit Date Child Phase
# 4       618 - Part B eligibility not determined  2016-12-03        IFSP
# 8                         618 - Parent withdraw  2016-09-22        IFSP
# 15                        618 - Part B eligible  2017-02-01        IFSP
# 16                        618 - Part B eligible  2017-01-13        IFSP
# 18                        618 - Part B eligible  2017-02-03        IFSP
# ...                                         ...         ...         ...
# 112126                 618 - Moved out of state  2022-06-27        IFSP
# 112129                    618 - Parent withdraw  2022-06-13        IFSP
# 112174                    618 - Parent withdraw  2022-06-08        IFSP
# 112689   618 - Attempts to contact unsuccessful  2022-07-01        IFSP
# 113003                    618 - Parent withdraw  2022-06-23        IFSP
#
# [36040 rows x 8 columns]

# %%
TEIS_Exit['third_DOB'] = pd.to_datetime(TEIS_Exit['third_DOB'])
TEIS_Exit['third_DOB']
# Out:
# C:\Users\marti\AppData\Local\Temp\ipykernel_20804\2100382324.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TEIS_Exit['third_DOB'] = pd.to_datetime(TEIS_Exit['third_DOB'])
# 4        2016-12-04
# 8        2016-12-24
# 15       2017-02-02
# 16       2017-01-14
# 18       2017-02-04
#             ...
# 112126   2024-12-09
# 112129   2022-08-26
# 112174   2023-04-24
# 112689   2024-09-26
# 113003   2023-10-11
# Name: third_DOB, Length: 36040, dtype: datetime64[ns]

# %%
TEIS_Exit["Exit Date"] = pd.to_datetime(TEIS_Exit['Exit Date'])
# Out:
# C:\Users\marti\AppData\Local\Temp\ipykernel_20804\1525979668.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TEIS_Exit["Exit Date"] = pd.to_datetime(TEIS_Exit['Exit Date'])

# %%
TEIS_Exit["Age of Exit"] = TEIS_Exit["Exit Date"] - TEIS_Exit["DOB"]
TEIS_Exit
# Out:
# C:\Users\marti\AppData\Local\Temp\ipykernel_20804\2633957898.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TEIS_Exit["Age of Exit"] = TEIS_Exit["Exit Date"] - TEIS_Exit["DOB"]
#        POE     Service Coordinator  Child ID        DOB  third_DOB  \
# 4       UC              Anna Bolin    353805 2013-12-04 2016-12-04
# 8       ET            Kristi Borer    354276 2013-12-24 2016-12-24
# 15      ET             Karen Stock    358011 2014-02-02 2017-02-02
# 16      FT      Jennifer Terranera    358031 2014-01-14 2017-01-14
# 18      FT         Kathy  Jeffries    358765 2014-02-04 2017-02-04
# ...     ..                     ...       ...        ...        ...
# 112126  SC              Kelly Holt    527606 2021-12-09 2024-12-09
# 112129  MD          Torkwase Smith    527609 2019-08-26 2022-08-26
# 112174  SC   Brittney Blalock Rose    527688 2020-04-24 2023-04-24
# 112689  MD          Marian Kingery    528318 2021-09-26 2024-09-26
# 113003  ET  Mischelle Helterbridle    528675 2020-10-11 2023-10-11
#
#                                     Exit Reason  Exit Date Child Phase  \
# 4       618 - Part B eligibility not determined 2016-12-03        IFSP
# 8                         618 - Parent withdraw 2016-09-22        IFSP
# 15                        618 - Part B eligible 2017-02-01        IFSP
# 16                        618 - Part B eligible 2017-01-13        IFSP
# 18                        618 - Part B eligible 2017-02-03        IFSP
# ...                                         ...        ...         ...
# 112126                 618 - Moved out of state 2022-06-27        IFSP
# 112129                    618 - Parent withdraw 2022-06-13        IFSP
# 112174                    618 - Parent withdraw 2022-06-08        IFSP
# 112689   618 - Attempts to contact unsuccessful 2022-07-01        IFSP
# 113003                    618 - Parent withdraw 2022-06-23        IFSP
#
#        Age of Exit
# 4        1095 days
# 8        1003 days
# 15       1095 days
# 16       1095 days
# 18       1095 days
# ...            ...
# 112126    200 days
# 112129   1022 days
# 112174    775 days
# 112689    278 days
# 113003    620 days
#
# [36040 rows x 9 columns]

# %%
TEIS_Exit["Age of Exit"] = TEIS_Exit["Age of Exit"].dt.days.astype(int)
# Out:
# C:\Users\marti\AppData\Local\Temp\ipykernel_20804\246842160.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TEIS_Exit["Age of Exit"] = TEIS_Exit["Age of Exit"].dt.days.astype(int)

# %%
TEIS_Exit = TEIS_Exit[TEIS_Exit['Age of Exit']  < 1095]
TEIS_Exit
# Out:
#        POE     Service Coordinator  Child ID        DOB  third_DOB  \
# 8       ET            Kristi Borer    354276 2013-12-24 2016-12-24
# 22      MD            Karen Hunter    360748 2014-01-29 2017-01-29
# 52      GN        Jennifer Johnson    364743 2014-03-13 2017-03-13
# 57      ET            Cathy Taylor    365848 2014-04-03 2017-04-03
# 67      SW        Elizabeth Hailey    368391 2014-06-15 2017-06-15
# ...     ..                     ...       ...        ...        ...
# 112126  SC              Kelly Holt    527606 2021-12-09 2024-12-09
# 112129  MD          Torkwase Smith    527609 2019-08-26 2022-08-26
# 112174  SC   Brittney Blalock Rose    527688 2020-04-24 2023-04-24
# 112689  MD          Marian Kingery    528318 2021-09-26 2024-09-26
# 113003  ET  Mischelle Helterbridle    528675 2020-10-11 2023-10-11
#
#                                     Exit Reason  Exit Date Child Phase  \
# 8                         618 - Parent withdraw 2016-09-22        IFSP
# 22      618 - Part B eligibility not determined 2017-01-27        IFSP
# 52                        618 - Parent withdraw 2016-07-08        IFSP
# 57       618 - Attempts to contact unsuccessful 2016-10-12        IFSP
# 93338             618 - Part B eligibility not determined 2022-04-01
# 93769             618 - Part B eligibility not determined 2022-03-04
# 94213             618 - Part B eligibility not determined 2021-12-22
# 94607   618 - Not eligible for Part B – Exit with refe... 2022-05-13
# 94872                               618 - Part B eligible 2022-02-11
# 95650             618 - Part B eligibility not determined 2021-11-05
# 95898             618 - Part B eligibility not determined 2022-04-22
# 96084             618 - Part B eligibility not determined 2022-04-29
# 97225             618 - Part B eligibility not determined 2022-05-06
# 97283             618 - Part B eligibility not determined 2022-05-27
# 97908             618 - Part B eligibility not determined 2021-10-22
# 98685             618 - Part B eligibility not determined 2022-02-25
# 98960             618 - Part B eligibility not determined 2022-01-28
# 99016             618 - Part B eligibility not determined 2021-12-03
# 99281             618 - Part B eligibility not determined 2022-05-06
# 99296             618 - Part B eligibility not determined 2022-04-14
# 99851                               618 - Part B eligible 2022-02-11
# 100136            618 - Part B eligibility not determined 2021-12-17
# 101098                              618 - Part B eligible 2022-05-13
# 101257            618 - Part B eligibility not determined 2022-05-06
# 102283            618 - Part B eligibility not determined 2022-04-08
# 102331            618 - Part B eligibility not determined 2022-01-27
# 102945            618 - Part B eligibility not determined 2022-05-27
# 103845                              618 - Part B eligible 2022-04-08
# 104169            618 - Part B eligibility not determined 2022-04-01
# 104666            618 - Part B eligibility not determined 2022-04-08
# 105681                              618 - Part B eligible 2022-03-25
# 105958            618 - Part B eligibility not determined 2022-05-27
# 108091            618 - Part B eligibility not determined 2022-05-13
#
#        Child Phase  Age of Exit
# 93114         IFSP         1094
# 93338         IFSP         1094
# 93769         IFSP         1094
# 94213         IFSP         1094
# 94607         IFSP         1094
# 94872         IFSP         1094
# 95650         IFSP         1094
# 95898         IFSP         1094
# 96084         IFSP         1094
# 97225         IFSP         1094
# 97283         IFSP         1094
# 97908         IFSP         1094
# 98685         IFSP         1094
# 98960         IFSP         1094
# 99016         IFSP         1094
# 99281         IFSP         1094
# 99296         IFSP         1094
# 99851         IFSP         1094
# 100136        IFSP         1094
# 101098        IFSP         1094
# 101257        IFSP         1094
# 102283        IFSP         1094
# 102331        IFSP         1094
# 102945        IFSP         1094
# 103845        IFSP         1094
# 104169        IFSP         1094
# 104666        IFSP         1094
# 105681        IFSP         1094
# 105958        IFSP         1094
# 108091        IFSP         1094

# %%
TEIS_Check2 = TEIS_Exit[TEIS_Exit['Age of Exit']  == 1093]
TEIS_Check2.tail(40)
# Out:
#        POE Service Coordinator  Child ID        DOB  third_DOB  \
# 89443   GN  Marguarite Stewart    498796 2019-06-27 2022-06-27
# 89643   GN     Marisa Nicklaus    498995 2019-03-21 2022-03-21
# 89817   FT     Kathy  Jeffries    499208 2018-07-05 2021-07-05
# 90193   GN     Marisa Nicklaus    499628 2019-05-09 2022-05-09
# 90300   GN       Jessica Shook    499748 2019-05-09 2022-05-09
# 90341   GN       Jessica Shook    499798 2019-05-30 2022-05-30
# 91821             618 - Part B eligibility not determined 2022-03-04
# 91929   618 - Completion of IFSP/ no longer requires s... 2022-04-07
# 92039                               618 - Parent withdraw 2022-01-14
# 92478             618 - Part B eligibility not determined 2022-04-22
# 92684             618 - Part B eligibility not determined 2022-01-07
# 92714             618 - Part B eligibility not determined 2021-10-29
# 92870                               618 - Part B eligible 2021-12-03
# 93757                               618 - Part B eligible 2022-05-06
# 93779             618 - Part B eligibility not determined 2022-05-13
# 94438             618 - Part B eligibility not determined 2022-05-20
# 94838             618 - Part B eligibility not determined 2022-05-18
# 95227             618 - Part B eligibility not determined 2021-12-30
# 96358             618 - Part B eligibility not determined 2022-06-17
# 96800             618 - Part B eligibility not determined 2022-01-21
# 97682             618 - Part B eligibility not determined 2022-03-25
# 98112             618 - Part B eligibility not determined 2022-01-21
# 98914             618 - Part B eligibility not determined 2022-02-11
# 99660                               618 - Part B eligible 2022-04-29
# 99839             618 - Part B eligibility not determined 2022-04-08
# 99912             618 - Part B eligibility not determined 2022-04-01
# 100118            618 - Part B eligibility not determined 2022-06-10
# 100683                              618 - Part B eligible 2022-02-11
# 100751                              618 - Part B eligible 2022-04-22
# 100827  618 - Not eligible for Part B – Exit with no r... 2022-07-01
# 102171            618 - Part B eligibility not determined 2022-04-01
# 102732                              618 - Part B eligible 2021-12-22
# 102949            618 - Part B eligibility not determined 2022-05-06
# 103773            618 - Part B eligibility not determined 2022-05-27
# 103939            618 - Part B eligibility not determined 2022-04-29
# 109787            618 - Part B eligibility not determined 2022-06-10
#
#        Child Phase  Age of Exit
# 89443         IFSP         1093
# 89643         IFSP         1093
# 89817         IFSP         1093
# 90193         IFSP         1093
# 90300         IFSP         1093
# 90341         IFSP         1093
# 90364         IFSP         1093
# 90371         IFSP         1093
# 90584         IFSP         1093
# 90980         IFSP         1093
# 91821         IFSP         1093
# 91929         IFSP         1093
# 92039         IFSP         1093
# 92478         IFSP         1093
# 92684         IFSP         1093
# 92714         IFSP         1093
# 92870         IFSP         1093
# 93757         IFSP         1093
# 93779         IFSP         1093
# 94438         IFSP         1093
# 94838         IFSP         1093
# 95227         IFSP         1093
# 96358         IFSP         1093
# 96800         IFSP         1093
# 97682         IFSP         1093
# 98112         IFSP         1093
# 98914         IFSP         1093
# 99660         IFSP         1093
# 99839         IFSP         1093
# 99912         IFSP         1093
# 100118        IFSP         1093
# 100683        IFSP         1093
# 100751        IFSP         1093
# 100827        IFSP         1093
# 102171        IFSP         1093
# 102732        IFSP         1093
# 102949        IFSP         1093
# 103773        IFSP         1093
# 103939        IFSP         1093
# 109787        IFSP         1093

# %%
TEIS_Check3 = TEIS_Exit[TEIS_Exit['Age of Exit']  == 1092]
TEIS_Check3.tail(30)
# Out:
#        POE Service Coordinator  Child ID        DOB  third_DOB  \
# 77254   GN         Kira Nemeth    486263 2018-07-06 2021-07-06
# 77546   GN       Alexis Seaton    486574 2017-11-29 2020-11-29
# 88781             618 - Part B eligibility not determined 2022-01-14
# 89000   618 - Not eligible for Part B – Exit with refe... 2022-02-18
# 91049                               618 - Part B eligible 2022-02-18
# 91369             618 - Part B eligibility not determined 2021-07-02
# 95012                               618 - Part B eligible 2022-01-14
# 97312                               618 - Part B eligible 2021-11-24
# 100295                              618 - Part B eligible 2022-04-14
# 101423                              618 - Part B eligible 2022-01-14
# 101687                              618 - Part B eligible 2022-05-27
# 103544             618 - Attempts to contact unsuccessful 2022-04-29
# 103970            618 - Part B eligibility not determined 2022-06-06
#
#        Child Phase  Age of Exit
# 77254         IFSP         1092
# 77546         IFSP         1092
# 78107         IFSP         1092
# 78964         IFSP         1092
# 79433         IFSP         1092
# 79943         IFSP         1092
# 81671         IFSP         1092
# 82479         IFSP         1092
# 82675         IFSP         1092
# 82679         IFSP         1092
# 85133         IFSP         1092
# 85148         IFSP         1092
# 85468         IFSP         1092
# 85965         IFSP         1092
# 86898         IFSP         1092
# 87418         IFSP         1092
# 87690         IFSP         1092
# 87702         IFSP         1092
# 87721         IFSP         1092
# 88781         IFSP         1092
# 89000         IFSP         1092
# 91049         IFSP         1092
# 91369         IFSP         1092
# 95012         IFSP         1092
# 97312         IFSP         1092
# 100295        IFSP         1092
# 101423        IFSP         1092
# 101687        IFSP         1092
# 103544        IFSP         1092
# 103970        IFSP         1092

# %%
TEIS_Exit = TEIS_Exit[TEIS_Exit['Age of Exit']  < 1092]
TEIS_Exit

TEIS_Exit = TEIS_Exit[TEIS_Exit['Exit Reason']  != "618 - Deceased"]
TEIS_Exit

TEIS_Exit = TEIS_Exit[TEIS_Exit['Exit Reason']  != "618 - Completion of IFSP/ no longer requires services"]
TEIS_Exit

TEIS_Exit = TEIS_Exit[TEIS_Exit['Exit Reason']  != "618 - Moved out of state"]
TEIS_Exit

TEIS_Exit_Poe = TEIS_Exit.groupby("POE").count()["Age of Exit"]
TEIS_Exit_Poe



TEIS_Exit_Poe = TEIS_Exit.groupby("POE").count()["Age of Exit"]
TEIS_Exit_Poe = TEIS_Exit_Poe.to_frame()
TEIS_Exit_Poe


TEIS_Exit_Poe_merge = pd.merge(TEIS_Exit_Poe, TEIS_All_Exits, on = ['POE'], how = 'inner')
TEIS_Exit_Poe_merge['Rate of Exit'] = TEIS_Exit_Poe_merge['Age of Exit']/TEIS_Exit_Poe_merge['Child ID']*100
TEIS_Exit_Poe_merge

TEIS_Exit_SC = TEIS_Exit.groupby("Service Coordinator").count()["Age of Exit"]
TEIS_Exit_SC = TEIS_Exit_SC.to_frame()
TEIS_Exit_SC




TEIS_Exit_SC_merge2 = pd.merge(TEIS_Exit_SC, TEIS_All_Exits2, on = ['Service Coordinator'], how = 'inner')
TEIS_Exit_SC_merge2['Rate of Exit'] = TEIS_Exit_SC_merge2['Age of Exit']/TEIS_Exit_SC_merge2['Child ID']*100
TEIS_Exit_SC_merge2.sort_values(by = "Rate of Exit")
