# %%
import pandas as pd
import operator
import time
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
TEIS_Monthly = pd.read_csv('../data/TEIS_Monthly.csv')

# %%
TEIS_July = pd.read_csv('../data/TEIS_July.csv')

# %%
TEIS_Monthly.head()
# Out:
#   POE  Child ID        DOB County Name    County SES   Child Phase Active  \
# 0  ET    403339   8/9/2014      Blount  Transitional   Eligibility      A
# 1  FT    404085  7/31/2013      Unicoi       At-Risk  Notification      I
# 2  FT    403623   2/5/2016    Sullivan  Transitional   Eligibility      A
# 3  FT    404157  12/6/2015    Sullivan  Transitional          IFSP      A
# 4  FT    404154  4/18/2015     Hawkins       At-Risk          IFSP      A
#
#             Service Coordinator Notification/ Referral Date  \
# 0                  Kristi Borer                    7/1/2016
# 1  Jennifer Terranera - 45 days                    7/1/2016
# 2                   Amy Talbert                    7/1/2016
# 3                Candice Cradic                    7/1/2016
# 4                Kathy Jeffries                    7/1/2016
#
#   Parent Consent Date  ... Service Coordinator Counter Fiscal Year.1  \
# 0            7/1/2016  ...                           1          2016
# ...

# %%
TEIS_Monthly.shape
# Out:
# (113256, 34)

# %%
TEIS_July.head()
# Out:
#   POE  Child ID         DOB County Name   County SES    Child Phase Active  \
# 0  ET    411812  12/14/2016      Blount  Transitional  Notification      I
# 1  ET    417398    4/6/2015        Knox  Transitional   Eligibility      I
# 2  ET    419400    3/4/2016       Roane  Transitional  Notification      I
# 3  ET    397571   5/11/2015        Knox  Transitional   Eligibility      I
# 4  ET    404648   9/23/2015        Knox  Transitional          IFSP      I
#
#   Service Coordinator Notification Date Parent Consent Date  \
# 0      Charity Decker        12/16/2016                 NaN
# 1     Jackie Campbell         4/24/2017            5/2/2017
# 2      Kelly Brackney          6/6/2017                 NaN
# 3        Wendy Burton         5/24/2017           6/13/2017
# 4         Sarah Scott         7/18/2016           7/28/2016
#
#   Referral Source Type Name Initial Eligibility Initial Eligibility Date  \
# 0                       DCS                 NaN                      NaN
# ...

# %%
TEIS_Monthly.groupby(by= 'Child ID').count()
# Out:
#           POE  DOB  County Name  County SES  Child Phase  Active  \
# Child ID
# 104085      1    1            1           1            1       1
# 350065      1    1            1           1            1       1
# 351755      1    1            1           1            1       1
# 353800      1    1            1           1            1       1
# 353805      1    1            1           1            1       1
# ...       ...  ...          ...         ...          ...     ...
# 529587      1    1            1           1            1       1
# 529597      1    1            1           1            1       1
# 529599      1    1            1           1            1       1
# 529606      1    1            1           1            1       1
# 529609      1    1            1           1            1       1
#
#           Service Coordinator  Notification/ Referral Date  \
# Child ID
# 104085                      0                            1
# ...

# %%
slicerdf = TEIS_Monthly[['Child ID', 'POE', 'Notification/ Referral Date','Fiscal Year', 'County Name', 'Notification Year']]
slicerdf
# Out:
#         Child ID POE Notification/ Referral Date Fiscal Year County Name  \
# 0         403339  ET                    7/1/2016   2016-2017      Blount
# 1         404085  FT                    7/1/2016   2016-2017      Unicoi
# 2         403623  FT                    7/1/2016   2016-2017    Sullivan
# 3         404157  FT                    7/1/2016   2016-2017    Sullivan
# 4         404154  FT                    7/1/2016   2016-2017     Hawkins
# ...          ...  ..                         ...         ...         ...
# 113251    528759  UC                   5/16/2022   2021-2022      Sumner
# 113252    528534  UC                   5/11/2022   2021-2022      Sumner
# 113253    528430  UC                   5/10/2022   2021-2022  Cumberland
# 113254    528253  UC                    5/6/2022   2021-2022      Sumner
# 113255    528535  UC                   5/11/2022   2021-2022       Smith
#
#         Notification Year
# 0                    2016
# 1                    2016
# ...

# %%
dups_df = slicerdf.loc[slicerdf.duplicated(subset='Child ID', keep=False)]
dups_df
# Out:
#         Child ID POE Notification/ Referral Date Fiscal Year County Name  \
# 2         403623  FT                    7/1/2016   2016-2017    Sullivan
# 6         404087  GN                    7/1/2016   2016-2017    Davidson
# 7         402274  GN                    7/1/2016   2016-2017  Montgomery
# 11        404074  MD                    7/1/2016   2016-2017      Shelby
# 14        404081  MD                    7/1/2016   2016-2017      Shelby
# ...          ...  ..                         ...         ...         ...
# 113225    508343  UC                   5/25/2022   2021-2022      Putnam
# 113235    512956  UC                    5/9/2022   2021-2022      Sumner
# 113241    497416  UC                   5/10/2022   2021-2022      Warren
# 113246    527351  UC                   5/10/2022   2021-2022      Sumner
# 113248    516784  UC                    5/4/2022   2021-2022      Warren
#
#         Notification Year
# 2                    2016
# 6                    2016
# ...

# %%
dups_df.sort_values(by = "Child ID")
# Out:
#         Child ID POE Notification/ Referral Date Fiscal Year County Name  \
# 8326      360966  ET                   1/12/2017   2016-2017      Monroe
# 6007      360966  ET                  11/10/2016   2016-2017      Monroe
# 5441      361021  ET                  10/28/2016   2016-2017    Anderson
# 6658      361021  ET                  11/29/2016   2016-2017    Anderson
# 5189      361038  GN                  10/24/2016   2016-2017      Wilson
# ...          ...  ..                         ...         ...         ...
# 111573    527636  ET                   5/27/2022   2021-2022      Blount
# 110585    527691  MD                   4/28/2022   2021-2022      Shelby
# 112414    527691  MD                   5/20/2022   2021-2022      Shelby
# 111752    527751  FT                   5/17/2022   2021-2022    Sullivan
# 109913    527751  FT                   4/28/2022   2021-2022    Sullivan
#
#         Notification Year
# 8326                 2017
# 6007                 2016
# ...

# %%
dups_df.groupby('Child ID').count()
# Out:
#           POE  Notification/ Referral Date  Fiscal Year  County Name  \
# Child ID
# 360966      2                            2            2            2
# 361021      2                            2            2            2
# 361038      2                            2            2            2
# 361040      2                            2            2            2
# 363098      2                            2            2            2
# ...       ...                          ...          ...          ...
# 527583      2                            2            2            2
# 527603      2                            2            2            2
# 527636      2                            2            2            2
# 527691      2                            2            2            2
# 527751      2                            2            2            2
#
#           Notification Year
# Child ID
# 360966                    2
# 361021                    2
# 361038                    2
# ...

# %%
dups_df.groupby(['POE', 'Child ID'], as_index = False).count()
# Out:
#       POE  Child ID  Notification/ Referral Date  Fiscal Year  County Name  \
# 0      ET    360966                            2            2            2
# 1      ET    361021                            2            2            2
# 2      ET    361040                            2            2            2
# 3      ET    380077                            4            4            4
# 4      ET    381730                            3            3            3
# ...    ..       ...                          ...          ...          ...
# 16006  UC    525301                            2            2            2
# 16007  UC    527351                            2            2            2
# 16008  UC    527425                            2            2            2
# 16009  UC    527525                            2            2            2
# 16010  UC    527583                            2            2            2
#
#        Notification Year
# 0                      2
# ...

# %%
##stops_in_37207 = stops_by_zip.loc[stops_by_zip['zip'] == '37207']
dups_POE = dups_df.groupby(['POE', 'Child ID'], as_index = False).count()
dups_382142 = dups_double.loc[dups_double['Child ID']== 382142]
dups_382142
# Out:
#       POE  Child ID  Notification/ Referral Date  Fiscal Year  County Name  \
# 10019  NW    382142                            1            1            1
# 14786  UC    382142                            1            1            1
#
#        Notification Year
# 10019                  1
# 14786                  1

# %%
dups_df.groupby('Child ID', as_index = False).count()
# Out:
#        Child ID  POE  Notification/ Referral Date  Fiscal Year  County Name  \
# 0        360966    2                            2            2            2
# 1        361021    2                            2            2            2
# 2        361038    2                            2            2            2
# 3        361040    2                            2            2            2
# 4        363098    2                            2            2            2
# ...         ...  ...                          ...          ...          ...
# 15262    527583    2                            2            2            2
# 15263    527603    2                            2            2            2
# 15264    527636    2                            2            2            2
# 15265    527691    2                            2            2            2
# 15266    527751    2                            2            2            2
#
#        Notification Year
# 0                      2
# ...

# %%
dups_df_Child = dups_df.groupby('Child ID', as_index = False).count()
dups_df_Child.value_counts('Child ID')
# Out:
# Child ID
# 360966    1
# 478239    1
# 478181    1
# 478186    1
# 478188    1
#          ..
# 435298    1
# 435299    1
# 435308    1
# 435313    1
# 527751    1
# Length: 15267, dtype: int64

# %%
len(dups_POE)/len(TEIS_Monthly) * 100
# Out:
# 14.136999364272091

# %%
##accidents['Date and Time'] = pd.to_datetime(accidents['Date and Time'])
TEIS_Monthly['Notification Year'] = pd.to_datetime(TEIS_Monthly['Notification/ Referral Date']).dt.year

# %%
TEIS_Monthly.head()
# Out:
#   POE  Child ID        DOB County Name    County SES   Child Phase Active  \
# 0  ET    403339   8/9/2014      Blount  Transitional   Eligibility      A
# 1  FT    404085  7/31/2013      Unicoi       At-Risk  Notification      I
# 2  FT    403623   2/5/2016    Sullivan  Transitional   Eligibility      A
# 3  FT    404157  12/6/2015    Sullivan  Transitional          IFSP      A
# 4  FT    404154  4/18/2015     Hawkins       At-Risk          IFSP      A
#
#             Service Coordinator Notification/ Referral Date  \
# 0                  Kristi Borer                    7/1/2016
# 1  Jennifer Terranera - 45 days                    7/1/2016
# 2                   Amy Talbert                    7/1/2016
# 3                Candice Cradic                    7/1/2016
# 4                Kathy Jeffries                    7/1/2016
#
#   Parent Consent Date  ... Child Count 2012 Child Count 2013 Child Count  \
# 0            7/1/2016  ...           1              NaN              NaN
# ...

# %%
dups_df.groupby(['Notification Year', 'Child ID'], as_index = False).count()
# Out:
#        Notification Year  Child ID  POE  Notification/ Referral Date  \
# 0                   2016    360966    1                            1
# 1                   2016    361021    2                            2
# 2                   2016    361038    2                            2
# 3                   2016    361040    2                            2
# 4                   2016    363098    1                            1
# ...                  ...       ...  ...                          ...
# 24792               2022    527583    2                            2
# 24793               2022    527603    2                            2
# 24794               2022    527636    2                            2
# 24795               2022    527691    2                            2
# 24796               2022    527751    2                            2
#
#        Fiscal Year  County Name
# 0                1            1
# 1                2            2
# 2                2            2
# ...
